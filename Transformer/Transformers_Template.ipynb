# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# - 5.31 메모
#
#     - 오늘/현재 기준으로 묻거나, 시의성이 없어 현재를 기준으로 질문을 설정할 때, 지금 코드에는 현재 시각을 기준으로 가져오게 되어 있음 -> 이 부분을 일별 데일리 (평균 등) 값으로 대체 업글할지 고민중 -> **완료**
#
#     - 또한, 시간대/시간 시의성이 없이 날짜만 or 아무것도 없는(현재)의 경우 해당 날짜의 데일리 값으로 가져오는 것이 나을지 고민중 -> **완료**
#
#     - 어투의 제한이 있음. 존댓말/반말 결과 차이 어디까지 있는지 확인 필요
#
#     - 현재 문제점 발견: 5일 안의 날짜가 1일로 넘어가는 경우 계산식이 적용되지 않고 있음. 이 부분은 사실 구현 및 시현에는 지장이 없는 부분이긴 하나, 추후 시간이 된다면 고칠 필요는 반드시 있음 -> **제외**

# %% [markdown]
# - 5.31
#
#     - 데일리 API 가져옴. sentence_completion 이전에 날짜만 있거나, 아무것도 없는 케이스의 질문에대해 데일리 값으로 변수 값을 변경하기    -> **완료**
#     - 시간대별 기준 시간을 구체적으로 나누기 -> **완료**

# %% [markdown]
# - 6.6
#
#     - 날짜만 있거나, 시의성만 있는 경우 데이터의 답변에 "일 평균" 등의 키워드를 넣는 것이 더 좋아 보임 -> **완료**
#
#     - 옷, 음식 추가해야함 -> **완료**
#
#     - (재헌) 일상 질문 추가 -> **완료**

# %% [markdown]
# - 6.7
#
#     - 공통질문 @@라벨 "공통"으로 변경 -> **완료**
#     - 일상에서 "우산" 같은 날씨 키워드 데이터 제거 -> **완료**
#     - 미세먼지 추가, 자외선 QA 추가
#
#     - 공통 라벨 랜덤문장 작성 -> 코드 랜덤 추출 -> **완료**
#     - 기준별 템플릿 코드 -> **완료**
#
#     - 비와 -> 처리 해야함 -> **완료**
#     - 공통에 우산 같은 것들 있음 -> **완료**
#     - 채팅 설명 맨 위에 출력하기 (주의사항, 사용법 등)
#     - 다하면 부가기능 _ 지도, 꿀팁
#     - 데일리 날씨 번역(수범)
#     - GPS/채팅 지역 설정(자동 채팅 반영 -> 수범 지역 단위 알아봐주기 -> 정한 코드 API 함수내로 수정 -> 반영
#     - 뉴스 셀렉트 박스에 ... 으로 아니고, 지역, 키워드 라고 할 수 있는지?

# %% [markdown]
# - 화요일 영상 전까지 역할 분배
#
#     - 하은:
#         - 여름철 음식 리스트 good/best + 사유 -> **완료**
#         - 2차 공통 템플릿 적용 -> **완료**
#         @@공통온도@@ 리스트 = ['ㅈㅇㅈㅇ','ㅈㅇㅈ0','ㅈㅇㅈㅇ','ㅈㅇㅈㅇ'] # 3개~5개 정도
#         @@공통강수@@ 리스트 = ['ㅈㅇㅈㅇ','ㅈㅇㅈ0','ㅈㅇㅈㅇ','ㅈㅇㅈㅇ']
#         if "@@공통온도@@" in output2:
#              x = 공통온도 리스트 중 랜덤 1개
#              output2 = output2.replace("@@공통온도@@", x)
#
#         - 지도 빼고 부가기능 (문구/이모티콘 출력) 트라이 해보고 안되는거 말해주기
#
#     - 정한:
#         - 기준별 템플릿 코드 노가다 -> **완료**
#         - 옷추천, 음식 추천(여름) 데이터셋 만들기 + 학습 + 템플릿 -> **완료**
#         - 부가기능 지도 + @
#         - 채팅 상단 안내메세지 작성하기
#         - 수범이 GPS 지역 변경 코드 작성
#
#         - 미세먼지/먼지/자외선 처리

# %% [markdown]
# - GPS 동의를 전체어플 기준으로 한번 받기
#
# - 뉴스 - 셀렉트박스 지역/날씨값
#
# - 채팅 - GPS기반으로 채팅 - 셀렉트박스 지역
#
# - 날씨디테일 - GPS기반 - 셀렉트박스 지역
#
# - 셀렉트 박스로 지역 커버
#
# - 위치 셀박 내용 - 현재위치, 서울, 부산, 대구, 인천, 광주, 대전, 울산, 제주
#
# - 아이폰 동의 허용안나옴.
#
# - 포스터 및 ppt에 앱 접속시 위치정보 동의 눌러주세요 언급
#
# - 뉴스 사진 - > 너무 커서 일반 폰은 안나옴

# %% [markdown]
# - 시현회 이전
#
#     - 평탄화: 자연스러운 문장으로 전체 검토 필요
#     - 자율 테스트 피드백
#     - 아이폰 위치설정
#     - 일반 폰 크기에 맞게
#     - 지역 셀박 완성 -> **완료**
#     - 지도 사진 삽입 -> **완료**
#     - 세종대 - 현재위치 비슷하게 뜨는지 확인 (위도 경도)
#     - 캐싱
#     - 날씨 summary 문장 계속 테스트 번역
#     - 지도 우의, 비예보
#     - 데이터에 지금 현재 -> **완료**
#     - 몇도야 -> 이거 인식 안됨
#     - 몇 도야? 이것도 -> 심플 데이터 체크해봐야함
#     - 플롯 소수점 제한걸기
#     - 뉴스기사에 요약 - 수치 처리
#     - 자외선 대체
#     - 맞춤법 및 5일, API기반 날씨 정보 제공용 -> 지식기반 X

# %% [markdown]
# 웨디는 사전지식 기반 챗봇이 아닌, API 기반 날씨 정보 제공 중심의 서비스입니다.
# 날씨 정보에 대한 질문은 최대 5일 후까지 답변이 가능하며,
# 맞춤법 및 띄어쓰기를 맞추어 주시면 더욱 좋은 답변을 확인하실 수 있습니다!

# %% [markdown]
# # 사전 정의

# %%
import pandas as pd
import re
import tensorflow_datasets as tfds
import tensorflow as tf
file_path = '/content/drive/MyDrive/캡스톤/3. 기말 발표/모델링/데이터 셋/통합 데이터셋/통합 데이터셋_20696_v9.csv'
train_data = pd.read_csv(file_path)
train_data.head()

questions = []
for sentence in train_data['Q']:
    # 구두점에 대해서 띄어쓰기

    # ex) 12시 땡! -> 12시 땡 !
    sentence = re.sub(r"([?.!,])", r" \1 ", sentence)
    sentence = sentence.strip()
    questions.append(sentence)


answers = []
for sentence in train_data['A']:
    # 구두점에 대해서 띄어쓰기
    # ex) 12시 땡! -> 12시 땡 !
    sentence = re.sub(r"([?.!,])", r" \1 ", sentence)
    sentence = sentence.strip()
    answers.append(sentence)


len(questions)


print(questions[:5])
print(answers[:5])

# 서브워드텍스트인코더를 사용하여 질문과 답변을 모두 포함한 단어 집합(Vocabulary) 생성
tokenizer = tfds.deprecated.text.SubwordTextEncoder.build_from_corpus(
    questions + answers, target_vocab_size=2**13)

# 시작 토큰과 종료 토큰에 대한 정수 부여.
START_TOKEN, END_TOKEN = [tokenizer.vocab_size], [tokenizer.vocab_size + 1]

# 시작 토큰과 종료 토큰을 고려하여 단어 집합의 크기를 + 2
VOCAB_SIZE = tokenizer.vocab_size + 2

MAX_LENGTH = 120
# Out:
# ['12시 땡 !', '3박4일 놀러가고 싶다', '3박4일 놀러가고 싶다', '3박4일 정도 놀러가고 싶다', 'PPL 심하네']
# ['하루가 또 가네요 .', '위로해 드립니다 .', '여행은 언제나 좋죠 .', '여행은 언제나 좋죠 .', '눈살이 찌푸려지죠 .']

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20985 entries, 0 to 20984
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Q       20985 non-null  object
#  1   A       20985 non-null  object
#  2   label   20985 non-null  object
# dtypes: object(3)
# memory usage: 492.0+ KB

# %%
def loss_function(y_true, y_pred):
  y_true = tf.reshape(y_true, shape=(-1, MAX_LENGTH - 1))

  loss = tf.keras.losses.SparseCategoricalCrossentropy(
      from_logits=True, reduction='none')(y_true, y_pred)

  mask = tf.cast(tf.not_equal(y_true, 0), tf.float32)
  loss = tf.multiply(loss, mask)

  return tf.reduce_mean(loss)

# %%
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):

    def __init__(self, d_model, warmup_steps=4000):
        super(CustomSchedule, self).__init__()
        self.d_model = float(d_model)  # d_model을 float로 초기화
        self.warmup_steps = int(warmup_steps)

    def __call__(self, step):
        step_float = tf.cast(step, tf.float32)
        arg1 = tf.math.rsqrt(step_float)
        arg2 = step_float * (self.warmup_steps**-1.5)

        return tf.math.rsqrt(self.d_model) * tf.math.minimum(arg1, arg2)

    def get_config(self):
        # 클래스 초기화 인자를 딕셔너리 형태로 반환합니다.
        return {
            "d_model": self.d_model,
            "warmup_steps": self.warmup_steps
        }

# %%
def create_padding_mask(x):
  mask = tf.cast(tf.math.equal(x, 0), tf.float32)
  # (batch_size, 1, 1, key의 문장 길이)
  return mask[:, tf.newaxis, tf.newaxis, :]

# %%
def create_look_ahead_mask(x):
  seq_len = tf.shape(x)[1]
  look_ahead_mask = 1 - tf.linalg.band_part(tf.ones((seq_len, seq_len)), -1, 0)
  padding_mask = create_padding_mask(x) # 패딩 마스크도 포함
  return tf.maximum(look_ahead_mask, padding_mask)

# %%
def scaled_dot_product_attention(query, key, value, mask):
  # query 크기 : (batch_size, num_heads, query의 문장 길이, d_model/num_heads)
  # key 크기 : (batch_size, num_heads, key의 문장 길이, d_model/num_heads)
  # value 크기 : (batch_size, num_heads, value의 문장 길이, d_model/num_heads)
  # padding_mask : (batch_size, 1, 1, key의 문장 길이)

  # Q와 K의 곱. 어텐션 스코어 행렬.
  matmul_qk = tf.matmul(query, key, transpose_b=True)

  # 스케일링
  # dk의 루트값으로 나눠준다.
  depth = tf.cast(tf.shape(key)[-1], tf.float32)
  logits = matmul_qk / tf.math.sqrt(depth)

  # 마스킹. 어텐션 스코어 행렬의 마스킹 할 위치에 매우 작은 음수값을 넣는다.
  # 매우 작은 값이므로 소프트맥스 함수를 지나면 행렬의 해당 위치의 값은 0이 된다.
  if mask is not None:
    logits += (mask * -1e9)

  # 소프트맥스 함수는 마지막 차원인 key의 문장 길이 방향으로 수행된다.
  # attention weight : (batch_size, num_heads, query의 문장 길이, key의 문장 길이)
  attention_weights = tf.nn.softmax(logits, axis=-1)

  # output : (batch_size, num_heads, query의 문장 길이, d_model/num_heads)
  output = tf.matmul(attention_weights, value)

  return output, attention_weights

class CustomMultiHeadAttention(tf.keras.layers.Layer):

  def __init__(self, d_model, num_heads, name="multi_head_attention"):
    super(CustomMultiHeadAttention, self).__init__(name=name)
    self.num_heads = num_heads
    self.d_model = d_model

    assert d_model % self.num_heads == 0

    # d_model을 num_heads로 나눈 값.
    # 논문 기준 : 64
    self.depth = d_model // self.num_heads

    # WQ, WK, WV에 해당하는 밀집층 정의
    self.query_dense = tf.keras.layers.Dense(units=d_model)
    self.key_dense = tf.keras.layers.Dense(units=d_model)
    self.value_dense = tf.keras.layers.Dense(units=d_model)

    # WO에 해당하는 밀집층 정의
    self.dense = tf.keras.layers.Dense(units=d_model)

  # num_heads 개수만큼 q, k, v를 split하는 함수
  def split_heads(self, inputs, batch_size):
    inputs = tf.reshape(
        inputs, shape=(batch_size, -1, self.num_heads, self.depth))
    return tf.transpose(inputs, perm=[0, 2, 1, 3])

  def call(self, inputs):
    query, key, value, mask = inputs['query'], inputs['key'], inputs[
        'value'], inputs['mask']
    batch_size = tf.shape(query)[0]

    # 1. WQ, WK, WV에 해당하는 밀집층 지나기
    # q : (batch_size, query의 문장 길이, d_model)
    # k : (batch_size, key의 문장 길이, d_model)
    # v : (batch_size, value의 문장 길이, d_model)
    # 참고) 인코더(k, v)-디코더(q) 어텐션에서는 query 길이와 key, value의 길이는 다를 수 있다.
    query = self.query_dense(query)
    key = self.key_dense(key)
    value = self.value_dense(value)

    # 2. 헤드 나누기
    # q : (batch_size, num_heads, query의 문장 길이, d_model/num_heads)
    # k : (batch_size, num_heads, key의 문장 길이, d_model/num_heads)
    # v : (batch_size, num_heads, value의 문장 길이, d_model/num_heads)
    query = self.split_heads(query, batch_size)
    key = self.split_heads(key, batch_size)
    value = self.split_heads(value, batch_size)

    # 3. 스케일드 닷 프로덕트 어텐션. 앞서 구현한 함수 사용.
    # (batch_size, num_heads, query의 문장 길이, d_model/num_heads)
    scaled_attention, _ = scaled_dot_product_attention(query, key, value, mask)
    # (batch_size, query의 문장 길이, num_heads, d_model/num_heads)
    scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3])

    # 4. 헤드 연결(concatenate)하기
    # (batch_size, query의 문장 길이, d_model)
    concat_attention = tf.reshape(scaled_attention,
                                  (batch_size, -1, self.d_model))

    # 5. WO에 해당하는 밀집층 지나기
    # (batch_size, query의 문장 길이, d_model)
    outputs = self.dense(concat_attention)

    return outputs

# %%
class PositionalEncoding(tf.keras.layers.Layer):
  def __init__(self, position, d_model):
    super(PositionalEncoding, self).__init__()
    self.pos_encoding = self.positional_encoding(position, d_model)

  def get_angles(self, position, i, d_model):
    angles = 1 / tf.pow(10000, (2 * (i // 2)) / tf.cast(d_model, tf.float32))
    return position * angles

  def positional_encoding(self, position, d_model):
    angle_rads = self.get_angles(
        position=tf.range(position, dtype=tf.float32)[:, tf.newaxis],
        i=tf.range(d_model, dtype=tf.float32)[tf.newaxis, :],
        d_model=d_model)

    # 배열의 짝수 인덱스(2i)에는 사인 함수 적용
    sines = tf.math.sin(angle_rads[:, 0::2])

    # 배열의 홀수 인덱스(2i+1)에는 코사인 함수 적용
    cosines = tf.math.cos(angle_rads[:, 1::2])

    angle_rads = np.zeros(angle_rads.shape)
    angle_rads[:, 0::2] = sines
    angle_rads[:, 1::2] = cosines
    pos_encoding = tf.constant(angle_rads)
    pos_encoding = pos_encoding[tf.newaxis, ...]

    #print(pos_encoding.shape)
    return tf.cast(pos_encoding, tf.float32)

  def call(self, inputs):
    return inputs + self.pos_encoding[:, :tf.shape(inputs)[1], :]

# %%
# 사용자 정의 객체 등록
tf.keras.utils.get_custom_objects().update({'CustomSchedule': CustomSchedule})
tf.keras.utils.get_custom_objects().update({'loss_function': loss_function})
tf.keras.utils.get_custom_objects().update({'create_padding_mask': create_padding_mask})
tf.keras.utils.get_custom_objects().update({'create_look_ahead_mask': create_look_ahead_mask})
tf.keras.utils.get_custom_objects().update({'CustomMultiHeadAttention': CustomMultiHeadAttention})
tf.keras.utils.get_custom_objects().update({'PositionalEncoding': PositionalEncoding})

# %% [markdown]
# # 모델 불러오기

# %%
# 모델 불러오기

import tensorflow as tf

# 저장된 모델의 경로
saved_model_path = '/content/drive/MyDrive/캡스톤/3. 기말 발표/모델링/트랜스포머/transformer_v10'
# 모델 불러오기
loaded_model = tf.keras.models.load_model(saved_model_path)

# %%
import tensorflow as tf
import re

def evaluate(sentence, model):
  sentence = preprocess_sentence(sentence)

  sentence = tf.expand_dims(
      START_TOKEN + tokenizer.encode(sentence) + END_TOKEN, axis=0)

  output = tf.expand_dims(START_TOKEN, 0)

  for i in range(MAX_LENGTH):
    predictions = model(inputs=[sentence, output], training=False)

    predictions = predictions[:, -1:, :]
    predicted_id = tf.cast(tf.argmax(predictions, axis=-1), tf.int32)

    if tf.equal(predicted_id, END_TOKEN[0]):
      break

    output = tf.concat([output, predicted_id], axis=-1)

  return tf.squeeze(output, axis=0)

def predict(sentence, model):
  prediction = evaluate(sentence, model)

  predicted_sentence = tokenizer.decode(
      [i for i in prediction if i < tokenizer.vocab_size])

  return predicted_sentence

def preprocess_sentence(sentence):
  sentence = re.sub(r"([?.!,])", r" \1 ", sentence)
  sentence = sentence.strip()
  return sentence

# %% [markdown]
# ---

# %% [markdown]
# # 데일리 API

# %%
import requests
import json
from geopy.geocoders import Nominatim

def fetch_weather_data(api_key):
    city = "Seoul"
    apikey = "327389fd33def65a6deed3ebfc2df470"
    api = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={apikey}"
    loc = requests.get(api)
    loc = json.loads(loc.text)
    # 'coord' 키를 사용하여 'lat'와 'lon' 값을 추출
    lat = loc['coord']['lat']
    lon = loc['coord']['lon']
    api_key = '69688b165f9dc2376196570c34bdd33f'
    url = f'https://api.openweathermap.org/data/3.0/onecall?lat={lat}&lon={lon}&exclude=minutely,alerts&appid={api_key}&units=metric'

    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        return data
    else:
        print(f'Failed to fetch weather data: {response.status_code}')
        return None

def print_daily_weather(data):
    daily_list = []
    if data:
        daily_weather = data['daily']
        for day in daily_weather:

            # 날짜
            dt = day['dt']

            # 날씨
            wet = day['summary']

            # 일 평균 기온
            temp_day = day['temp']['day']

            # 일 최고 기온
            temp_day_max = day['temp']['max']

            # 일 최저 기온
            temp_day_min = day['temp']['min']

            # 풍속
            wind_speed = day['wind_speed']

            # 강수량
            day_rain = day.get('rain', 0)

            # 강수확률
            day_pop = str(float(day['pop']) * 100)

            # 자외선
            uvi = day['uvi']

            # 대기압
            day_pressure = day['pressure']

            # 습도
            day_humidity = day['humidity']

            # 적설량
            day_snow = 0

            # 가시거리
            day_visibility = '측정값 없음'

            daily = {'dt':dt, 'wet':wet, 'temp_day':temp_day, 'temp_day_max': temp_day_max, 'temp_day_min' : temp_day_min, 'wind_speed' : wind_speed, 'day_rain' : day_rain, 'day_pop': day_pop, 'uvi' : uvi, 'day_pressure' : day_pressure,
                     'day_humidity':day_humidity, 'day_snow': day_snow, 'day_visibility':day_visibility}
            daily_list.append(daily)
    return daily_list
api_key = '69688b165f9dc2376196570c34bdd33f'  # 발급받은 API 키로 교체하세요.
weather_data = fetch_weather_data(api_key)
daily_list = []
daily_list = print_daily_weather(weather_data)
daily_list = daily_list[:6]

daily_list
# Out:
# [{'dt': 1718334000,
#   'wet': 'Expect a day of partly cloudy with clear spells',
#   'temp_day': 30.74,
#   'temp_day_max': 31.96,
#   'temp_day_min': 22.77,
#   'wind_speed': 5.19,
#   'day_rain': 0,
#   'day_pop': '0.0',
#   'uvi': 7.91,
#   'day_pressure': 1005,
#   'day_humidity': 40,
#   'day_snow': 0,
#   'day_visibility': '측정값 없음'},
#  {'dt': 1718420400,
#   'wet': 'Expect a day of partly cloudy with rain',
#   'temp_day': 22.03,
#   'temp_day_max': 24.49,
#   'temp_day_min': 20.48,
#   'wind_speed': 2.35,
#   'day_rain': 2.48,
#   'day_pop': '100.0',
#   'uvi': 4.38,
#   'day_pressure': 1005,
#   'day_humidity': 74,
#   'day_snow': 0,
#   'day_visibility': '측정값 없음'},
#  {'dt': 1718506800,
#   'wet': 'There will be rain until morning, then clearing',
#   'temp_day': 28.74,
#   'temp_day_max': 30.58,
#   'temp_day_min': 19.05,
#   'wind_speed': 5.1,
#   'day_rain': 0.32,
#   'day_pop': '86.0',
#   'uvi': 7.13,
#   'day_pressure': 1006,
#   'day_humidity': 33,
#   'day_snow': 0,
#   'day_visibility': '측정값 없음'},
#  {'dt': 1718593200,
#   'wet': 'The day will start with clear sky through the late morning hours, transitioning to partly cloudy',
#   'temp_day': 28.65,
#   'temp_day_max': 28.98,
#   'temp_day_min': 20.01,
#   'wind_speed': 5.7,
#   'day_rain': 0,
#   'day_pop': '0.0',
#   'uvi': 7.77,
#   'day_pressure': 1008,
#   'day_humidity': 27,
#   'day_snow': 0,
#   'day_visibility': '측정값 없음'},
#  {'dt': 1718679600,
#   'wet': 'There will be partly cloudy until morning, then clearing',
#   'temp_day': 29.38,
#   'temp_day_max': 30.79,
#   'temp_day_min': 20.95,
#   'wind_speed': 4.19,
#   'day_rain': 0,
#   'day_pop': '0.0',
#   'uvi': 7.65,
#   'day_pressure': 1006,
#   'day_humidity': 38,
#   'day_snow': 0,
#   'day_visibility': '측정값 없음'},
#  {'dt': 1718766000,
#   'wet': 'The day will start with clear sky through the late morning hours, transitioning to partly cloudy',
#   'temp_day': 31.19,
#   'temp_day_max': 31.19,
#   'temp_day_min': 21.92,
#   'wind_speed': 4.23,
#   'day_rain': 0,
#   'day_pop': '0.0',
#   'uvi': 8,
#   'day_pressure': 1009,
#   'day_humidity': 32,
#   'day_snow': 0,
#   'day_visibility': '측정값 없음'}]

# %%
for i in daily_list:
    print(i['wet'])
# Out:
# Expect a day of partly cloudy with clear spells
# Expect a day of partly cloudy with rain
# There will be rain until morning, then clearing
# The day will start with clear sky through the late morning hours, transitioning to partly cloudy
# There will be partly cloudy until morning, then clearing
# The day will start with clear sky through the late morning hours, transitioning to partly cloudy

# %% [markdown]
# Expect a day of partly cloudy with clear spells
#
# The day will start with clear sky through the late morning hours, transitioning to partly cloudy
#
# Expect a day of partly cloudy with rain
#
# There will be clear sky today
#
# You can expect clear sky in the morning, with partly cloudy in the afternoon
#
# There will be partly cloudy today
#
# Expect a day of partly cloudy with clear spells
#
# The day will start with clear sky through the late morning hours, transitioning to partly cloudy
#
# Expect a day of partly cloudy with rain
#
# There will be clear sky today
#
# You can expect clear sky in the morning, with partly cloudy in the afternoon
#
# There will be partly cloudy today
#
# Expect a day of partly cloudy with clear spells
#
# The day will start with clear sky through the late morning hours, transitioning to partly cloudy
#
# Expect a day of partly cloudy with rain
#
# There will be clear sky today
#
# You can expect clear sky in the morning, with partly cloudy in the afternoon
#
# There will be partly cloudy today

# %% [markdown]
# # 완성_템플릿 실행 함수

# %%
import requests
import json
import pandas as pd

city = "Seoul"
apikey = "327389fd33def65a6deed3ebfc2df470"
api = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={apikey}"

loc = requests.get(api)
loc = json.loads(loc.text)

# %%
# 'coord' 키를 사용하여 'lat'와 'lon' 값을 추출
lat = loc['coord']['lat']
lon = loc['coord']['lon']

# %%
apikey = "327389fd33def65a6deed3ebfc2df470"
api = f"http://api.openweathermap.org/data/2.5/forecast?lat={lat}&lon={lon}&units=metric&appid={apikey}"

result = requests.get(api)

# %%
result = json.loads(result.text)
#result

# %%
temp = result.copy()

# %%
temp
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1718344800,
#    'main': {'temp': 32.21,
#     'feels_like': 31.45,
#     'temp_min': 32.21,
#     'temp_max': 32.72,
#     'pressure': 1004,
#     'sea_level': 1004,
#     'grnd_level': 994,
#     'humidity': 33,
#     'temp_kf': -0.51},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 16},
#    'wind': {'speed': 4.65, 'deg': 254, 'gust': 4.15},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-14 06:00:00'},
#   {'dt': 1718355600,
#    'main': {'temp': 30.81,
#     'feels_like': 29.83,
#     'temp_min': 30.23,
#     'temp_max': 30.81,
#     'pressure': 1003,
#     'sea_level': 1003,
#     'grnd_level': 994,
#     'humidity': 33,
#     'temp_kf': 0.58},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 11},
#    'wind': {'speed': 5.19, 'deg': 277, 'gust': 4.64},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-14 09:00:00'},
#   {'dt': 1718366400,
#    'main': {'temp': 25.59,
#     'feels_like': 25.46,
#     'temp_min': 25.59,
#     'temp_max': 25.59,
#     'pressure': 1006,
#     'sea_level': 1006,
#     'grnd_level': 996,
#     'humidity': 48,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 45},
#    'wind': {'speed': 3.26, 'deg': 295, 'gust': 5.78},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-06-14 12:00:00'},
#   {'dt': 1718377200,
#    'main': {'temp': 24.49,
#     'feels_like': 24.46,
#     'temp_min': 24.49,
#     'temp_max': 24.49,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 996,
#     'humidity': 56,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.15, 'deg': 264, 'gust': 1.46},
#    'visibility': 10000,
#    'pop': 0.2,
#    'rain': {'3h': 0.1},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-06-14 15:00:00'},
#   {'dt': 1718388000,
#    'main': {'temp': 23.61,
#     'feels_like': 23.65,
#     'temp_min': 23.61,
#     'temp_max': 23.61,
#     'pressure': 1004,
#     'sea_level': 1004,
#     'grnd_level': 995,
#     'humidity': 62,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.05, 'deg': 189, 'gust': 0.96},
#    'visibility': 10000,
#    'pop': 0.25,
#    'rain': {'3h': 0.14},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-06-14 18:00:00'},
#   {'dt': 1718398800,
#    'main': {'temp': 22.46,
#     'feels_like': 22.64,
#     'temp_min': 22.46,
#     'temp_max': 22.46,
#     'pressure': 1004,
#     'sea_level': 1004,
#     'grnd_level': 995,
#     'humidity': 72,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 0.38, 'deg': 315, 'gust': 0.48},
#    'visibility': 10000,
#    'pop': 0.55,
#    'rain': {'3h': 0.39},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-14 21:00:00'},
#   {'dt': 1718409600,
#    'main': {'temp': 22.56,
#     'feels_like': 22.73,
#     'temp_min': 22.56,
#     'temp_max': 22.56,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 995,
#     'humidity': 71,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.4, 'deg': 292, 'gust': 1.83},
#    'visibility': 10000,
#    'pop': 0.22,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-15 00:00:00'},
#   {'dt': 1718420400,
#    'main': {'temp': 22.03,
#     'feels_like': 22.22,
#     'temp_min': 22.03,
#     'temp_max': 22.03,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 995,
#     'humidity': 74,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 0.43, 'deg': 175, 'gust': 0.97},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 0.97},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-15 03:00:00'},
#   {'dt': 1718431200,
#    'main': {'temp': 22.6,
#     'feels_like': 22.85,
#     'temp_min': 22.6,
#     'temp_max': 22.6,
#     'pressure': 1003,
#     'sea_level': 1003,
#     'grnd_level': 994,
#     'humidity': 74,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.72, 'deg': 101, 'gust': 1.8},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 0.67},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-15 06:00:00'},
#   {'dt': 1718442000,
#    'main': {'temp': 24.49,
#     'feels_like': 24.61,
#     'temp_min': 24.49,
#     'temp_max': 24.49,
#     'pressure': 1003,
#     'sea_level': 1003,
#     'grnd_level': 993,
#     'humidity': 62,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 94},
#    'wind': {'speed': 1, 'deg': 278, 'gust': 1.75},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-15 09:00:00'},
#   {'dt': 1718452800,
#    'main': {'temp': 21.29,
#     'feels_like': 21.54,
#     'temp_min': 21.29,
#     'temp_max': 21.29,
#     'pressure': 1004,
#     'sea_level': 1004,
#     'grnd_level': 995,
#     'humidity': 79,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 60},
#    'wind': {'speed': 1.81, 'deg': 273, 'gust': 3.31},
#    'visibility': 10000,
#    'pop': 0.2,
#    'rain': {'3h': 0.32},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-06-15 12:00:00'},
#   {'dt': 1718463600,
#    'main': {'temp': 20.37,
#     'feels_like': 20.68,
#     'temp_min': 20.37,
#     'temp_max': 20.37,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 995,
#     'humidity': 85,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 1.15, 'deg': 238, 'gust': 1.61},
#    'visibility': 10000,
#    'pop': 0.86,
#    'rain': {'3h': 0.7},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-06-15 15:00:00'},
#   {'dt': 1718474400,
#    'main': {'temp': 19.63,
#     'feels_like': 19.95,
#     'temp_min': 19.63,
#     'temp_max': 19.63,
#     'pressure': 1004,
#     'sea_level': 1004,
#     'grnd_level': 995,
#     'humidity': 88,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 1.11, 'deg': 228, 'gust': 1.19},
#    'visibility': 10000,
#    'pop': 0.43,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-06-15 18:00:00'},
#   {'dt': 1718485200,
#    'main': {'temp': 19.23,
#     'feels_like': 19.53,
#     'temp_min': 19.23,
#     'temp_max': 19.23,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 996,
#     'humidity': 89,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 1},
#    'wind': {'speed': 1.51, 'deg': 207, 'gust': 2.15},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-15 21:00:00'},
#   {'dt': 1718496000,
#    'main': {'temp': 23.83,
#     'feels_like': 23.81,
#     'temp_min': 23.83,
#     'temp_max': 23.83,
#     'pressure': 1006,
#     'sea_level': 1006,
#     'grnd_level': 997,
#     'humidity': 59,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 1},
#    'wind': {'speed': 2.09, 'deg': 274, 'gust': 3.92},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-16 00:00:00'},
#   {'dt': 1718506800,
#    'main': {'temp': 28.74,
#     'feels_like': 27.84,
#     'temp_min': 28.74,
#     'temp_max': 28.74,
#     'pressure': 1006,
#     'sea_level': 1006,
#     'grnd_level': 996,
#     'humidity': 33,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 4.59, 'deg': 272, 'gust': 6.14},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-16 03:00:00'},
#   {'dt': 1718517600,
#    'main': {'temp': 30.58,
#     'feels_like': 28.9,
#     'temp_min': 30.58,
#     'temp_max': 30.58,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 995,
#     'humidity': 24,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 4.45, 'deg': 296, 'gust': 6.18},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-16 06:00:00'},
#   {'dt': 1718528400,
#    'main': {'temp': 27.28,
#     'feels_like': 26.92,
#     'temp_min': 27.28,
#     'temp_max': 27.28,
#     'pressure': 1006,
#     'sea_level': 1006,
#     'grnd_level': 996,
#     'humidity': 37,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 5.1, 'deg': 257, 'gust': 6.21},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-16 09:00:00'},
#   {'dt': 1718539200,
#    'main': {'temp': 23.95,
#     'feels_like': 23.68,
#     'temp_min': 23.95,
#     'temp_max': 23.95,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 998,
#     'humidity': 49,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 1.89, 'deg': 225, 'gust': 2.57},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-06-16 12:00:00'},
#   {'dt': 1718550000,
#    'main': {'temp': 22.07,
#     'feels_like': 21.9,
#     'temp_min': 22.07,
#     'temp_max': 22.07,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 999,
#     'humidity': 60,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 1},
#    'wind': {'speed': 2.18, 'deg': 209, 'gust': 3.5},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-06-16 15:00:00'},
#   {'dt': 1718560800,
#    'main': {'temp': 20.74,
#     'feels_like': 20.46,
#     'temp_min': 20.74,
#     'temp_max': 20.74,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 999,
#     'humidity': 61,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 0.96, 'deg': 216, 'gust': 1.13},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-06-16 18:00:00'},
#   {'dt': 1718571600,
#    'main': {'temp': 20.21,
#     'feels_like': 19.96,
#     'temp_min': 20.21,
#     'temp_max': 20.21,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 999,
#     'humidity': 64,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 1},
#    'wind': {'speed': 1.02, 'deg': 162, 'gust': 1.49},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-16 21:00:00'},
#   {'dt': 1718582400,
#    'main': {'temp': 24.84,
#     'feels_like': 24.48,
#     'temp_min': 24.84,
#     'temp_max': 24.84,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 999,
#     'humidity': 42,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 13},
#    'wind': {'speed': 2.07, 'deg': 220, 'gust': 3.55},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-17 00:00:00'},
#   {'dt': 1718593200,
#    'main': {'temp': 28.65,
#     'feels_like': 27.44,
#     'temp_min': 28.65,
#     'temp_max': 28.65,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 998,
#     'humidity': 27,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 73},
#    'wind': {'speed': 4.59, 'deg': 231, 'gust': 6.01},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-17 03:00:00'},
#   {'dt': 1718604000,
#    'main': {'temp': 28.98,
#     'feels_like': 27.7,
#     'temp_min': 28.98,
#     'temp_max': 28.98,
#     'pressure': 1006,
#     'sea_level': 1006,
#     'grnd_level': 997,
#     'humidity': 27,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 74},
#    'wind': {'speed': 5.7, 'deg': 235, 'gust': 7.89},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-17 06:00:00'},
#   {'dt': 1718614800,
#    'main': {'temp': 26.33,
#     'feels_like': 26.33,
#     'temp_min': 26.33,
#     'temp_max': 26.33,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 996,
#     'humidity': 37,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 96},
#    'wind': {'speed': 4.6, 'deg': 233, 'gust': 7.62},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-17 09:00:00'},
#   {'dt': 1718625600,
#    'main': {'temp': 23.78,
#     'feels_like': 23.52,
#     'temp_min': 23.78,
#     'temp_max': 23.78,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 997,
#     'humidity': 50,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 86},
#    'wind': {'speed': 2.41, 'deg': 223, 'gust': 4.92},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-06-17 12:00:00'},
#   {'dt': 1718636400,
#    'main': {'temp': 22.35,
#     'feels_like': 22.21,
#     'temp_min': 22.35,
#     'temp_max': 22.35,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 998,
#     'humidity': 60,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 13},
#    'wind': {'speed': 1.88, 'deg': 228, 'gust': 4.67},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-06-17 15:00:00'},
#   {'dt': 1718647200,
#    'main': {'temp': 21.37,
#     'feels_like': 21.31,
#     'temp_min': 21.37,
#     'temp_max': 21.37,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 997,
#     'humidity': 67,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 6},
#    'wind': {'speed': 1.15, 'deg': 182, 'gust': 1.53},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-06-17 18:00:00'},
#   {'dt': 1718658000,
#    'main': {'temp': 20.95,
#     'feels_like': 20.9,
#     'temp_min': 20.95,
#     'temp_max': 20.95,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 997,
#     'humidity': 69,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 1},
#    'wind': {'speed': 0.9, 'deg': 170, 'gust': 1.46},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-17 21:00:00'},
#   {'dt': 1718668800,
#    'main': {'temp': 25.39,
#     'feels_like': 25.29,
#     'temp_min': 25.39,
#     'temp_max': 25.39,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 997,
#     'humidity': 50,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 1},
#    'wind': {'speed': 2.25, 'deg': 228, 'gust': 3.17},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-18 00:00:00'},
#   {'dt': 1718679600,
#    'main': {'temp': 29.38,
#     'feels_like': 28.81,
#     'temp_min': 29.38,
#     'temp_max': 29.38,
#     'pressure': 1006,
#     'sea_level': 1006,
#     'grnd_level': 996,
#     'humidity': 38,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 3.49, 'deg': 243, 'gust': 3.39},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-18 03:00:00'},
#   {'dt': 1718690400,
#    'main': {'temp': 30.79,
#     'feels_like': 30.13,
#     'temp_min': 30.79,
#     'temp_max': 30.79,
#     'pressure': 1004,
#     'sea_level': 1004,
#     'grnd_level': 995,
#     'humidity': 36,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 1},
#    'wind': {'speed': 4.19, 'deg': 237, 'gust': 3.22},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-18 06:00:00'},
#   {'dt': 1718701200,
#    'main': {'temp': 27.82,
#     'feels_like': 27.78,
#     'temp_min': 27.82,
#     'temp_max': 27.82,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 996,
#     'humidity': 44,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 3.63, 'deg': 235, 'gust': 4.17},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-18 09:00:00'},
#   {'dt': 1718712000,
#    'main': {'temp': 24.73,
#     'feels_like': 24.75,
#     'temp_min': 24.73,
#     'temp_max': 24.73,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 997,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.41, 'deg': 220, 'gust': 3.67},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-06-18 12:00:00'},
#   {'dt': 1718722800,
#    'main': {'temp': 23.37,
#     'feels_like': 23.51,
#     'temp_min': 23.37,
#     'temp_max': 23.37,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 998,
#     'humidity': 67,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.23, 'deg': 203, 'gust': 3.89},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-06-18 15:00:00'},
#   {'dt': 1718733600,
#    'main': {'temp': 22.39,
#     'feels_like': 22.59,
#     'temp_min': 22.39,
#     'temp_max': 22.39,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 999,
#     'humidity': 73,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 1.89, 'deg': 202, 'gust': 4.06},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-06-18 18:00:00'},
#   {'dt': 1718744400,
#    'main': {'temp': 21.92,
#     'feels_like': 22.1,
#     'temp_min': 21.92,
#     'temp_max': 21.92,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1000,
#     'humidity': 74,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 2},
#    'wind': {'speed': 1.41, 'deg': 147, 'gust': 2.56},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-18 21:00:00'},
#   {'dt': 1718755200,
#    'main': {'temp': 26.38,
#     'feels_like': 26.38,
#     'temp_min': 26.38,
#     'temp_max': 26.38,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1000,
#     'humidity': 53,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 26},
#    'wind': {'speed': 1.63, 'deg': 181, 'gust': 1.69},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-19 00:00:00'},
#   {'dt': 1718766000,
#    'main': {'temp': 31.19,
#     'feels_like': 30.13,
#     'temp_min': 31.19,
#     'temp_max': 31.19,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 999,
#     'humidity': 32,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.59, 'deg': 248, 'gust': 2.46},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-19 03:00:00'}],
#  'city': {'id': 1835848,
#   'name': 'Seoul',
#   'coord': {'lat': 37.5683, 'lon': 126.9778},
#   'country': 'KR',
#   'population': 10349312,
#   'timezone': 32400,
#   'sunrise': 1718309419,
#   'sunset': 1718362472}}

# %%
from datetime import datetime, timedelta, date
import re
import numpy as np
import pytz

def senetence_completion(input):#여기서의 인자 input은 실제 모델링으로 출력된 output1
    global avg
    # "평균" 추가용


    # 원하는 시간대 설정 (예: 'Asia/Seoul'은 서울 시간대를 의미)
    timezone = pytz.timezone('Asia/Seoul')

    # 현재 시각을 해당 시간대로 설정
    now = datetime.now(timezone)

    # 현재 시각을 "YYYY-MM-DD HH:MM:SS" 형식의 문자열로 변환
    formatted_now = now.strftime("%Y-%m-%d %H:%M:%S")
    #print("현재시각:",formatted_now)


    date_list_after = ['내일', '모레','글피', '내일 모레', '1일 뒤', '2일 뒤', '3일 뒤', '4일 뒤', '5일 뒤']
    time_list = ['지금', '현재', '아침', '점심', '저녁', '오전', '오후', '낮', '밤','새벽']
    hour_list = ['0시','1시','2시','3시','4시','5시','6시','7시','8시','9시','10시','11시','12시',
                 '13시', '14시', '15시', '16시', '17시', '18시', '19시', '20시', '21시', '22시', '23시', '24시']
    # date_list_now의 원소 중 어느 하나라도 sent에 포함되어 있는지 확인
    temp_need = []
    temp_city = []
    found_keyword = None

    # 미래를 나타내는 키워드 확인
    for keyword in date_list_after:
        if keyword in input:
            found_keyword = keyword
            break
    day = 0
    # 특정 키워드가 없는 문장도 현재로 포함하여 계산

    if found_keyword:
        # 미래 키워드를 날짜별로 구분하여 가져오는 데이터 변경
        if found_keyword in ['내일', '1일 뒤']:
            day = 1
            daily = daily_list [1]
            for i in range(40):
                if int(formatted_now[8]+formatted_now[9])+ 1 == int(temp['list'][i]['dt_txt'][8]+temp['list'][i]['dt_txt'][9]):

                    temp_need.append(temp['list'][i])
                    #temp_city.append(temp['city'][i])
        if found_keyword in ['모레', '2일 뒤', '내일 모레']:
            day = 2
            daily = daily_list [2]
            for i in range(40):
                if int(formatted_now[8]+formatted_now[9])+ 2 == int(temp['list'][i]['dt_txt'][8]+temp['list'][i]['dt_txt'][9]):

                    temp_need.append(temp['list'][i])

                    #temp_city.append(temp['city'][i])
        if found_keyword in ['글피', '3일 뒤']:
            day = 3
            daily = daily_list [3]
            for i in range(40):
                if int(formatted_now[8]+formatted_now[9])+ 3 == int(temp['list'][i]['dt_txt'][8]+temp['list'][i]['dt_txt'][9]):

                    temp_need.append(temp['list'][i])
                    #temp_city.append(temp['city'][i])
        if found_keyword in ['4일 뒤']:
            day = 4
            daily = daily_list [4]
            for i in range(40):
                if int(formatted_now[8]+formatted_now[9])+ 4 == int(temp['list'][i]['dt_txt'][8]+temp['list'][i]['dt_txt'][9]):

                    temp_need.append(temp['list'][i])
                    #temp_city.append(temp['city'][i])
        if found_keyword in ['5일 뒤']:
            day = 5
            daily = daily_list [5]
            for i in range(40):
                if int(formatted_now[8]+formatted_now[9])+ 5 == int(temp['list'][i]['dt_txt'][8]+temp['list'][i]['dt_txt'][9]):

                    temp_need.append(temp['list'][i])
                    #temp_city.append(temp['city'][i])

    else:
        #(1) 날짜 키워드 값이 없는 경우 현재 날짜를 기준으로
            for i in range(40):
                daily = daily_list [0]
                if int(formatted_now[8]+formatted_now[9]) == int(temp['list'][i]['dt_txt'][8]+temp['list'][i]['dt_txt'][9]):

                    temp_need.append(temp['list'][i])
                    #temp_city.append(temp['city'][i])




    #print("기상측정 시간",temp_need)
    #print(temp_need)


    near_time = []

    global timestamp,temperature,lowest_temperature,highest_temperature,humidity,weather,rain,rain_pop, visibility, wind, pressure, snow, uvi
    # 시간 키워드가 있으면
    if (any(hour in input for hour in hour_list)):
        avg = 0
        # 시간대 키워드가 있으면
        if ("오후" in input) or ("낮" in input) or  ("점심" in input) or ("저녁" in input) or ("밤" in input):
            for i in range(len(temp_need)):
                matchs = re.search(r'(\d+)시', input)
                hour_str = matchs.group(1)
                hour = int(hour_str)
                if hour < 12:
                    hour += 12
                else: hour = hour

                #print(f"추출된 시간: {hour}")
                near = int(temp_need[i]['dt_txt'][11]+temp_need[i]['dt_txt'][12])
                #print('절대값',abs(now-near))
                near_time.append(abs(hour-near))

            ine = np.argmin(near_time)
        else:
            for i in range(len(temp_need)):
                matchs = re.search(r'(\d+)시', input)
                hour_str = matchs.group(1)
                hour = int(hour_str)
                #print(f"추출된 시간: {hour}")
                near = int(temp_need[i]['dt_txt'][11]+temp_need[i]['dt_txt'][12])
                #print('절대값',abs(now-near))
                near_time.append(abs(hour-near))
            #print(near_time)
            ine = np.argmin(near_time)
        i = ine # 시간대 값
        # 습도, 자외선, 구름양, 풍속, 기온, 최고기온, 최저기온, 강수량, 일출시간, 일몰시간,대기압, 강수확률, 강수량, 가시거리, 적설량, 적설확률
        # 시간대
        timestamp = temp_need[i]['dt_txt']

        # 온도
        temperature = temp_need[i]['main']['temp']
        #print(temp_need[i])
        # 최저 기온
        lowest_temperature = temp_need[i]['main']['temp_min']

        # 최고 기온
        highest_temperature = temp_need[i]['main']['temp_max']

        # 습도
        humidity = temp_need[i]['main']['humidity']

        # 날씨(구름양)
        weather = temp_need[i]['weather'][0]['main'] #Claer, Rain, Snow, Clouds등

        # 강수량 (지난 3시간동안)
        rain = temp_need[i]['rain']['3h'] if temp_need[i]['weather'][0]['main'] == 'rain' else 0

        # 강수확률
        rain_pop = (float(temp_need[i]['pop']) * 100)

        # 자외선
        uvi = daily['uvi']

        # 가시거리
        visibility = temp_need[i]['visibility']

        # 풍속
        wind = temp_need[i]['wind']['speed']

        # 대기압
        pressure = temp_need[i]['main']['pressure']

        # 적설량
        snow = temp_need[i]['snow']['3h'] if temp_need[i]['weather'][0]['main'] == 'snow' else 0

    # 시간 키워드가 없으면
    else:
        #시간대 키워드가 있으면
        if (any(time in input for time in time_list)):
            avg = 0
            if ("지금" in input) or ("현재" in input):
            #(2) 시간대 키워드 값이 없는 경우 현재 시간과 가장 가까운 측정 시간
                for i in range(len(temp_need)):
                    now = int(formatted_now[11]+formatted_now[12])
                    near = int(temp_need[i]['dt_txt'][11]+temp_need[i]['dt_txt'][12])
                    #print('절대값',abs(now-near))
                    near_time.append(abs(now-near))
                #print(near_time)
                ine = np.argmin(near_time)
                # 질문한 시각과 가장 가까운 날씨 정보 값의 index

            elif ("오전" in input) or ("아침" in input):
                for i in range(len(temp_need)):
                    near = int(temp_need[i]['dt_txt'][11]+temp_need[i]['dt_txt'][12])
                    near_time.append((near))
                #print(near_time)
                if 6 in near_time:
                    ine = near_time.index(6)
                elif 9 in near_time:
                    ine = near_time.index(9)
                elif 12 in near_time:
                    ine = near_time.index(12)
            elif ("낮" in input) or ("오후" in input) or ("점심" in input):
                for i in range(len(temp_need)):
                    near = int(temp_need[i]['dt_txt'][11]+temp_need[i]['dt_txt'][12])
                    near_time.append((near))
                #print(near_time)
                if 15 in near_time:
                    ine = near_time.index(15)
                elif 12 in near_time:
                    ine = near_time.index(12)
                #print("여기")
            elif ("저녁" in input):
                for i in range(len(temp_need)):
                    near = int(temp_need[i]['dt_txt'][11]+temp_need[i]['dt_txt'][12])
                    near_time.append((near))
                if 18 in near_time:
                    ine = near_time.index(18)
                elif 21 in near_time:
                    ine = near_time.index(21)
                elif 0 in near_time:
                    ine = near_time.index(0)
            elif ("밤" in input):
                for i in range(len(temp_need)):
                    near = int(temp_need[i]['dt_txt'][11]+temp_need[i]['dt_txt'][12])
                    near_time.append((near))
                if 18 in near_time:
                    ine = near_time.index(18)
                elif 21 in near_time:
                    ine = near_time.index(21)
                elif 0 in near_time:
                    ine = near_time.index(0)
            elif ("새벽" in input):
                for i in range(len(temp_need)):
                    near = int(temp_need[i]['dt_txt'][11]+temp_need[i]['dt_txt'][12])
                    near_time.append((near))
                if 3 in near_time:
                    ine = near_time.index(3)
                elif 6 in near_time:
                    ine = near_time.index(6)
                elif 0 in near_time:
                    ine = near_time.index(0)
            i = ine # 시간대 값
            # 습도, 자외선, 구름양, 풍속, 기온, 최고기온, 최저기온, 강수량, 일출시간, 일몰시간,대기압, 강수확률, 강수량, 가시거리, 적설량, 적설확률
            # 시간대
            timestamp = temp_need[i]['dt_txt']

            # 온도
            temperature = temp_need[i]['main']['temp']
            #print(temp_need[i])
            # 최저 기온
            lowest_temperature = temp_need[i]['main']['temp_min']

            # 최고 기온
            highest_temperature = temp_need[i]['main']['temp_max']

            # 습도
            humidity = temp_need[i]['main']['humidity']

            # 날씨(구름양)
            weather = temp_need[i]['weather'][0]['main'] #Claer, Rain, Snow, Clouds등

            # 강수량 (지난 3시간동안)
            rain = temp_need[i]['rain']['3h'] if temp_need[i]['weather'][0]['main'] == 'rain' else 0

            # 강수확률
            rain_pop = (float(temp_need[i]['pop']) * 100)

            # 가시거리
            visibility = temp_need[i]['visibility']

            # 풍속
            wind = temp_need[i]['wind']['speed']

            # 대기압
            pressure = temp_need[i]['main']['pressure']

            # 적설량
            snow = temp_need[i]['snow']['3h'] if temp_need[i]['weather'][0]['main'] == 'snow' else 0
        # 시간대 키워드가 없으면
        else:

            avg = 1
            # 날짜
            today = date.today()
            days_later = today + timedelta(days=day)
            timestamp = days_later.strftime('%Y-%m-%d')

            # 온도
            temperature = daily['temp_day']

            # 최저 기온
            lowest_temperature = daily['temp_day_min']

            # 최고 기온
            highest_temperature = daily['temp_day_max']

            # 습도
            humidity = daily['day_humidity']

            # 날씨(구름양)
            weather = daily['wet']

            # 강수량
            rain =  daily['day_rain']
            # 강수확률
            rain_pop = float(daily['day_pop'])

            # 자외선
            uvi = daily['uvi']

            # 가시거리
            visibility = daily['day_visibility']
            # 풍속
            wind = daily['wind_speed']

            # 대기압
            pressure = daily['day_pressure']

            # 적설량
            snow = 0

# %% [markdown]
# ---

# %%
import random

# 7개의 리스트를 파이썬 list 문법으로 변환
temperature_list = ['사람마다 느끼는 체감온도는 다를 수 있습니다.', '온도가 높을 때는 열사병에 주의해주세요.', '대체로 온도가 높은 날이 유지됩니다.', '기온에 맞는 옷차림을 준비해주세요.', '더위를 많이 타신다면 가벼운 옷차림을 추천드려요.']
precipitation_list = ['지역마다 강수확률은 차이가 있을 수 있습니다.', '강수확률은 같은 조건일 때 과거에 비가 몇 번 왔다는 것을 의미합니다.', '강수확률이 있다면 습도가 평소보다 높을 수 있습니다.', '강수량이 높다면 실내 창문을 닫아주세요.', '강수량이 높을 시에 보행과 운전에 주의하시기바랍니다.']
pressure_list = ['대기압은 공기의 무게로 한 표면에 가해지는 단위 면적당 힘으로 정의됩니다.', '주변 지역보다 대기압이 높다면 맑은 하늘을 보실 수 있습니다.', '주변 지역보다 대기압이 낮다면 하늘이 흐릴 수 있습니다.', '주변 지역과 기압 차이가 클 시 바람이 많이 불 수 있습니다.', '대기압의 기준은 주변 지역에 비해서 기압이 높은가 낮은가로 판단됩니다.']
humidity_list = ['높은 습도가 지속된다면 곰팡이 등을 주의해주세요.', '습도가 높을 시 불쾌지수가 높을 수 있습니다.', '습도가 낮을 시 건조함을 느낄 수 있습니다.', '습도가 낮다면 화재에 주의하셔야합니다.', '적절한 실내 습도 유지가 중요합니다.']
visibility_list = ['가시거리는 다양한 조건에 의해 결정됩니다.', '가시거리가 낮을 시 건물 등이 잘 확인 되지 않을 수 있습니다.', '가시거리가 낮다면 보행과 운전에 주의해주세요.', '시정이 낮다면 운전 등에 힘이 들 수 있습니다.', '날씨와 가시거리 둘 다 좋다면 등산을 하시는 것도 좋습니다.']
snowfall_list = ['눈이 조금 쌓였어도 마찰력이 크게 줄어드니 보행과 운전에 주의해주세요.', '눈이 많이 올 경우 도로상황에 지장을 줄 수 있으니 주의해주세요.', '눈이 많이 왔다면 외출에 주의해주세요.', '눈이 올 때는 따뜻한 호빵 어떠세요?', '눈이 오면 시야에 방해가 있을 수 있습니다.']
wind_speed_list = ['바람이 많이 불 경우 체온이 급격히 낮아질 수 있습니다.', '적절한 바람은 불쾌지수를 낮춰줍니다.', '바람이 많이 분다면 적절한 겉옷을 챙겨주세요.', '풍속 14m/s부터 강풍주의보가 발령됩니다.', '풍향은 바람이 불어오는 방향을 나타냅니다.']

# output2 문자열에서 @@공통@@ 패턴을 랜덤한 리스트 요소로 바꾸는 코드
def replace_common_patterns(output2):
    if "@@공통온도@@" in output2:
        x1 = random.choice(temperature_list) + "🌡"
        output2 = output2.replace("@@공통온도@@", "\n" + x1)
    if "@@공통강수@@" in output2:
        x2 = random.choice(precipitation_list) + "☂"
        output2 = output2.replace("@@공통강수@@","\n" +  x2)
    if "@@공통대기압@@" in output2:
        x3 = random.choice(pressure_list) + "☁"
        output2 = output2.replace("@@공통대기압@@", "\n" + x3)
    if "@@공통습도@@" in output2:
        x4 = random.choice(humidity_list) + "💧"
        output2 = output2.replace("@@공통습도@@", "\n" + x4)
    if "@@공통가시거리@@" in output2:
        x5 = random.choice(visibility_list) + "🌟"
        output2 = output2.replace("@@공통가시거리@@","\n" +  x5)
    if "@@공통적설량@@" in output2:
        x6 = random.choice(snowfall_list) + "❄"
        output2 = output2.replace("@@공통적설량@@","\n" + x6)
    if "@@공통풍속@@" in output2:
        x7 = random.choice(wind_speed_list) + "🌫"
        output2 = output2.replace("@@공통풍속@@", "\n" + x7)
    return output2

# %%
good_food = { "수박": "여름 대표 제철 과일입니다. 당도와 수분이 풍부합니다.", "포도": "제철 과일입니다. 씨없는 포도도 있습니다!", "토마토": "수분이 풍부하고 건강에 좋습니다!", "매실": "제철 음식입니다. 여름에 배탈이 나면 매실차를 먹으라는 말도 있습니다.", "참외": "제철 과일입니다. 식감이 뛰어납니다.", "복숭아": "여름 대표 제철 과일입니다. 당도와 맛이 훌륭합니다.", "갈치조림": "제철 요리입니다. 제주도에서 갈치가 유명합니다.", "전복": "대표적인 보양식이며, 익혀먹는 것이 더욱 좋습니다.", "추어탕": "여름철 보양식입니다. 지역마다 특징이 다르다고 합니다.", "장어": "대표 보양식 입니다. 원기 회복에 뛰어납니다.", "삼계탕": "대표 보양식 입니다. 원기 회복에 뛰어납니다.", "비빔밥": "한국의 대표적인 음식입니다. 소화가 편하고 사계절 먹습니다.", "오리고기": "활동량이 많은 여름에 불포화 지방산이 피로회복에 도움을 줍니다.", "비빔국수": "시원하고 매운 양념이 입맛을 돋움니다.", "물냉면": "차가운 음식으로 열감 해소에 좋습니다.", "비빔냉면": "시원하고 매운 양념이 입맛을 돋움니다.", "열무국수": "열무를 곁들인 시원한 음식으로 열감 해소에 좋습니다.", "화채": "차가운 음식으로 열감 해소에 좋고, 디저트로 많이 먹습니다.", "냉채족발": "열감해소와 보양에 도움이 됩니다.", "콩국수": "여름을 대표하는 계절 메뉴입니다. 고소한 맛이 일품입니다.", "막국수": "물막국수, 비빔막국수 등 다양하며 일부 지역마다 먹는 방법이 재미있는 여름 요리입니다.", "냉모밀": "차가운 음식으로 열감 해소에 도움이 됩니다.", "밀면": "차가운 음식으로 열감 해소에 도움이 됩니다. 부산에서 유명합니다.", "오이냉국": "시원한 음식으로 여름철 밥상에 자주 등장합니다.", "아이스크림": "열감해소와 당분보풍에 뛰어난 간식입니다.", "팥빙수": "여름 대표 간식입니다. 다양한 빙수들이 있습니다." }
bad_food = { "생선회": "여름철 회는 상하기 쉬워 주의해야합니다.", "활어회": "여름철 회는 상하기 쉬워 주의해야합니다.", "전복회": "여름철 회는 상하기 쉬워 주의해야합니다. 익혀먹는 것이 좋습니다.", "생굴": "여름철 생굴은 상하기 쉬워 주의해야합니다.", "육회": "여름철 회는 상하기 쉬워 주의해야합니다.", "날고기": "여름철 날고기는 상하기 쉬워 주의해야합니다. 익혀먹는 것이 좋습니다.", "날달걀": "여름철 날달걀은 상하기 쉬워 주의해야합니다.", "채소샐러드": "생채소가 섞여 있어 어떤 음식으로 탈이 났는지 알기 어렵습니다.", "유제품": "유제품은 상하기 쉽습니다.", "생크림 케이크": "유제품은 상하기 쉽습니다.", "푸딩": "유제품은 상하기 쉽습니다.", "조개구이": "해산물, 특히 조개는 여름철 반드시 익혀 먹어야 합니다. 또한, 상한 조개가 아닌지 확인하세요.", "두부조림": "두부는 상하기 쉬워요", "마요네즈": "마요네즈는 상하기 쉬워요", "에그마요": "마요네즈는 상하기 쉬워요", "간장게장": "게장과 젓갈류는 상하기 쉬워요", "양념게장": "게장과 젓갈류는 상하기 쉬워요", "굴젓": "게장과 젓갈류는 상하기 쉬워요", "낙지젓갈": "게장과 젓갈류는 상하기 쉬워요", "갈치젓갈": "게장과 젓갈류는 상하기 쉬워요", "물회": "날것의 회를 사용하기에 신선한지 잘 확인해야합니다.", "회덮밥": "날것의 회를 사용하기에 신선한지 잘 확인해야합니다." }

# %%
import requests
import folium
from folium import Popup

def get_nearby_convenience_stores(lat, lon, api_key):
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    params = {
        "location": f"{lat},{lon}",
        "radius": 1000,  # 반경 1km 내 검색
        "type": "convenience_store",
        "key": api_key
    }
    response = requests.get(url, params=params)
    return response.json()

# 예시: 내 위치의 위도와 경도
latitude = lat
longitude = lat
api_key = 'AIzaSyC-4c5H0cNBdele6suDFNBuec-155A7Guo'

convenience_stores = get_nearby_convenience_stores(latitude, longitude, api_key)

def plot_convenience_stores(stores, lat, lon):
    # 지도 생성 (줌 레벨을 17로 설정, 현재 위치를 중심으로 설정)
    map_ = folium.Map(location=[lat, lon], zoom_start=16)

    # 현재 위치 마커 추가
    current_location_popup = """
    <div style="white-space: nowrap; font-size: 12px; line-height: 0.5;">
        현재 위치
    </div>
    """
    folium.Marker(
        location=[lat, lon],
        popup=Popup(current_location_popup, show=True),
        icon=folium.Icon(color='blue')
    ).add_to(map_)

    # 편의점 마커 추가
    for store in stores['results']:
        # 간략한 팝업 내용
        brief_popup_content = f"""
        <div style="white-space: nowrap; font-size: 10px; line-height: 0.5;">
            <b>{store['name']}</b>
        </div>
        """
        detailed_popup_content = f"""
        <div style="white-space: nowrap; font-size: 10px; line-height: 0.5;">
            <b>{store['name']}</b><br>
            {store['vicinity']}
        </div>
        """

        # 마커 추가 (클릭 시 상세 내용 표시)
        marker = folium.Marker(
            location=[store['geometry']['location']['lat'], store['geometry']['location']['lng']],
            popup=Popup(brief_popup_content, show=True),
            icon=folium.Icon(color='red')
        ).add_to(map_)

        # JavaScript를 사용하여 클릭 시 상세 주소를 표시
        marker.add_child(folium.Popup(detailed_popup_content))
        marker.add_child(folium.ClickForMarker(popup=detailed_popup_content))

    return map_


#map_ = plot_convenience_stores(convenience_stores, latitude, longitude)
# 지도 저장 및 표시
#map_.save("convenience_stores_map.html")

# %% [markdown]
# # 생성 결과

# %%
# 사용 예시
import re

def remove_space_before_punctuation(text):
    corrected_text = re.sub(r'(?<=\S) (?=[.,!?])', '', text)
    corrected_text = re.sub(r'([.,!?])(\s)(\s*)', r'\1\3', corrected_text)
    return corrected_text


# 원하는 시간대 설정 (예: 'Asia/Seoul'은 서울 시간대를 의미)
timezone = pytz.timezone('Asia/Seoul')

# 현재 시각을 해당 시간대로 설정
now = datetime.now(timezone)

# 현재 시각을 "YYYY-MM-DD HH:MM:SS" 형식의 문자열로 변환
formatted_now = now.strftime("%Y-%m-%d %H:%M:%S")

time_list = ['{아침}', '{점심}', '{저녁}', '{오전}', '{오후}', '{낮}', '{밤}, {새벽}']

def replace_time_in_output(input_str, output_str, time_list):
    for time_word in time_list:
        if time_word in input_str:
            for out_time_word in time_list:
                if out_time_word in output_str:
                    return output_str.replace(out_time_word, time_word)
    return output_str

print(f"<현재 시각: {formatted_now}>")
print('======================')
while True:


    index = 0
    user_input = input("사용질문: ")
    if '엔' in user_input: user_input = user_input.replace('엔', '')
    if '요즘에는' in user_input: user_input = user_input.replace('요즘에는', '')
    if '지금은' in user_input: user_input = user_input.replace('지금은', '지금')
    if '낼' in user_input: user_input = user_input.replace('낼', '내일')
    if '어떤데' in user_input: user_input = user_input.replace('어떤데', '어때')
    if '더운데' in user_input: user_input = user_input.replace('더운데', '더워')

    if user_input == "종료":
        break

    output1 = predict(user_input , loaded_model)
    output1 = remove_space_before_punctuation(output1)
    output1 = replace_time_in_output(user_input , output1, time_list)

    if '지금' in user_input:
        if "오늘" in output1: output1 = output1.replace("오늘", "지금")
    elif '현재' in user_input:
        if "오늘" in output1: output1 = output1.replace("오늘", "현재")
    #print(output1)
    if "{" in output1 or "@@" in output1:
        avg = 0
        output2 = output1 # 초기화
        # 알맞는 시의성, 값 가져오기
        senetence_completion(output1)
        #print("모델생성: ",output2)
        ####################################
        # 1차 날씨 값 적용
        if "{온도}" in output1:
            if avg == 0: output2 = output2.replace("{온도}", str(temperature)+"℃")
            else: output2 = output2.replace("{온도}", "평균 " + str(temperature)+"℃")
        if "{최저온도}" in output1:
            output2 = output2.replace("{최저온도}", str(lowest_temperature)+"℃")
        if "{최고온도}" in output1:
            output2 = output2.replace("{최고온도}", str(highest_temperature)+"℃")
        if "{습도}" in output1:
            if avg == 0: output2 = output2.replace("{습도}", str(humidity)+"%")
            else: output2 = output2.replace("{습도}", "평균 " + str(humidity)+"%")
        if "{날씨}" in output1:
            # 날씨 영어 - 한글 변환
            if weather == 'Clear': weather = '맑은 날씨'
            elif weather == 'Rain':
                weather = '비오는 날씨'
            elif weather == 'Clouds':
                weather = '흐린 날씨'
            elif weather == 'Snow':
                weather = '눈오는 날씨'
            elif weather == 'Expect a day of partly cloudy with clear spells':
                weather = '맑은 가운데 부분적으로 흐린 날씨'
            elif weather == 'The day will start with clear sky through the late morning hours, transitioning to partly cloudy':
                weather = '오전 늦게까지 맑은 하늘로 시작하여, 부분적으로 흐려지는 날씨'
            elif weather == 'Expect a day of partly cloudy with rain':
                weather = '부분적으로 흐리고 비가 오는 날씨'
            elif weather == 'There will be clear sky today':
                weather = '하늘이 맑은 날씨'
            elif weather == 'You can expect clear sky in the morning, with partly cloudy in the afternoon':
                weather = '오전에는 맑고, 오후에는 부분적으로 흐린 날씨'
            elif weather == 'There will be partly cloudy today':
                weather = '부분적으로 흐린 날씨'

            output2 = output2.replace("{날씨}", weather)
        if "{강수량}" in output1:
            if avg == 0: output2 = output2.replace("{강수량}", str(rain)+"mm")
            else: output2 = output2.replace("{강수량}", "평균 " + str(rain)+"mm")
        if "{강수확률}" in output1:
            output2 = output2.replace("{강수확률}",  + str(rain_pop)+"%")
        if "{가시거리}" in output1:
            if avg == 0: output2 = output2.replace("{가시거리}", str(visibility)+"m")
            else: output2 = output2.replace("{가시거리}", "평균 " + str(visibility)+"m")
        if "{풍속}" in output1:
            if avg == 0: output2 = output2.replace("{풍속}", str(wind)+"m/s")
            else: output2 = output2.replace("{풍속}", "평균 " + str(wind)+"m/s")
        if "{대기압}" in output1:
            if avg == 0: output2 = output2.replace("{대기압}", str(pressure)+"hPa")
            else: output2 = output2.replace("{대기압}", "평균 " + str(pressure)+"hPa")
        if "{적설량}" in output1:
            if avg == 0: output2 = output2.replace("{적설량}", str(snow)+"mm")
            else: output2 = output2.replace("{적설량}", "평균 " + str(snow)+"mm")

        output2 = output2.replace("{", "").replace("}", "")

        ####################################
        # 2차 공통 템플릿 적용
        output2 = replace_common_patterns(output2)

        ####################################
        # 3차 날씨 세부 템플릿
        if "@@비예보@@" in output2:
            if rain == 0: output2 = output2.replace("@@비예보@@", "\n비가 오지 않습니다.")
            elif rain < 0.1: output2 = output2.replace("@@비예보@@","\n체감상으로 느껴지지 않는 빗방울입니다.")
            elif rain >= 1 and rain < 3: output2 = output2.replace("@@비예보@@","\n옷이 젖지 않을 정도의 강수입니다.")
            elif rain >= 3 and rain < 15: output2 = output2.replace("@@비예보@@","\n지면에 빗방울이 튀어 발밑이 젖을 수 있습니다.")
            elif rain >= 15 and rain < 30: output2 = output2.replace("@@비예보@@","\n하수도가 넘칠 수 있으니 주의가 필요합니다.\n\n⭐웨디의 꿀팁⭐ 강한 비가 예상되니 창문을 닫는 것을 추천드립니다.")
            elif rain >= 30: output2 = output2.replace("@@비예보@@","\n해당 비가 3시간동안 지속될 경우 호우주의보가 발령됩니다. 주의가 필요합니다.\n\n⭐웨디의 꿀팁⭐ 비가 많이 올 때엔 자주 TV등을 통해 기상상황을 확인하시는 것이 좋습니다.")

            output2 = output2+"\n\n우산이나 우의가 없으신 경우를 대비하여 근방의 편의점을 지도로 안내해드리겠습니다!"
            # 현재 위치와 편의점 데이터를 사용하여 지도 생성
            map_ = plot_convenience_stores(convenience_stores, latitude, longitude)
            # 지도 저장 및 표시
            map_.save("convenience_stores_map.html")
            index = 1

        if "@@우의@@" in output2:
            if rain_pop == 0: output2 = output2.replace("@@우의@@", "\n비가 오지 않습니다.")
            elif rain_pop < 30: output2 = output2.replace("@@우의@@","\n가벼운 외출이라면 우산이나 우의를 챙기지 않아도 괜찮습니다.")
            elif rain_pop >= 30 and rain_pop < 50: output2 = output2.replace("@@우의@@","\n작은 단우산을 가방에 넣고 가시는 걸 추천드립니다.")
            elif rain_pop >= 50 and rain_pop < 70: output2 = output2.replace("@@우의@@","\n우산이나 우의를 챙기시는 게 좋습니다.\n\n⭐웨디의 꿀팁⭐ 비가 올 때는 창문을 닫는게 좋습니다.")
            elif rain_pop >= 70 and rain_pop < 90: output2 = output2.replace("@@우의@@","\n비가 올 확률이 높으므로 반드시 우산이나 우의를 챙겨주세요.\n\n⭐웨디의 꿀팁⭐ 비가 많이 올 때는 보행해 주의하셔야 합니다.")
            elif rain_pop >= 90: output2 = output2.replace("@@우의@@","\n비가 오고 있으므로 우의나 우산을 챙기시는 게 좋겠습니다.\n\n⭐웨디의 꿀팁⭐ 바람이 많이 분다면 우산보다는 우의가 더 안전합니다.")


            output2 = output2+"\n\n우산이나 우의가 없으신 경우를 대비하여 근방의 편의점을 지도로 안내해드리겠습니다!"
            # 현재 위치와 편의점 데이터를 사용하여 지도 생성
            map_ = plot_convenience_stores(convenience_stores, latitude, longitude)
            # 지도 저장 및 표시
            map_.save("convenience_stores_map.html")
            index = 1

        if "@@장화@@" in output2:
            if rain_pop == 0: output2 = output2.replace("@@장화@@", "\n장화를 신지 않으시는 것이 좋을 것 같습니다.\n\n⭐웨디의 꿀팁⭐ 비가 오지 않는 여름엔 샌들을 신는 것도 좋습니다!")
            elif rain_pop < 30: output2 = output2.replace("@@장화@@", "\n가벼운 외출이라면 장화보단 다른 신발을 추천합니다.")
            elif rain_pop >= 30 and rain_pop < 50: output2 = output2.replace("@@장화@", "\n비가 올 수 있으나 장화보다는 다른 신발을 추천합니다.")
            elif rain_pop >= 50 and rain_pop < 70: output2 = output2.replace("@@장화@", "\n좋아하시는 장화가 있으시다면 신는 것이 좋습니다.")
            elif rain_pop >= 70 and rain_pop < 90: output2 = output2.replace("@@장화@", "\n비가 올 확률이 높으므로 장화를 신는 것도 좋겠습니다.\n\n⭐웨디의 꿀팁⭐ 비가 많이 온다면 길이가 긴 장화가 좋습니다.")
            elif rain_pop >= 90: output2 = output2.replace("@@장화@@", "\n비가 올 확률이 높으므로 장화를 신는 것을 추천드립니다.\n\n⭐웨디의 꿀팁⭐ 장화를 신으면 통풍이 안 되니 너무 오래 신지 않는 것이 좋습니다.")

        if "@@빨래@@" in output2:
            if rain_pop < 30: output2 = output2.replace("@@빨래@@","\n강수확률이 낮습니다. 필요시 빨래를 돌려도 될 것 같습니다.\n\n⭐웨디의 꿀팁⭐ 햇빛과 공기가 잘통하는 곳에 빨래를 말려보세요!")
            elif rain_pop >= 30 and rain_pop < 50: output2 = output2.replace("@@빨래@@","\n강수확률이 있습니다. 빨래는 추천드리지 않습니다.\n\n⭐웨디의 꿀팁⭐ 소량의 빨래라면 괜찮을 것 같아요!")
            elif rain_pop >= 50 and rain_pop < 70: output2 = output2.replace("@@빨래@@","\n강수확률이 높은 편입니다. 빨래는 추천드리지 않습니다.")
            elif rain_pop >= 70 and rain_pop < 90: output2 = output2.replace("@@빨래@@","\n강수확률이 높습니다. 다른 날에 빨래를 하는 것을 추천드립니다.\n\n⭐웨디의 꿀팁⭐ 습도가 높을 가능성이 커 빨래를 돌리신다면 제습기를 틀어주세요.")
            elif rain_pop >= 90: output2 = output2.replace("@@빨래@@","\n강수확률이 매우 높습니다. 빨래는 하면 안 될 것 같습니다.\n\n⭐웨디의 꿀팁⭐ 습도가 높을 가능성이 크니 온도가 낮지 않다면 에어컨을 트시는 것을 추천드립니다.")
        if "@@날씨@@" in output2:
            if rain_pop < 30: output2 = output2.replace("@@날씨@@","\n강수확률이 낮습니다. 야외 활동을 하셔도 될 것 같습니다.")
            elif rain_pop >= 30 and rain_pop < 50: output2 = output2.replace("@@날씨@@","\n강수확률이 있으므로 가벼운 외출이 바람직합니다.")
            elif rain_pop >= 50 and rain_pop < 70: output2 = output2.replace("@@날씨@@","\n강수확률이 높은 편입니다. 야외활동 시 우산을 챙겨주세요.\n\n⭐웨디의 꿀팁⭐ 야외활동이 길다면 우산은 작고 가벼운 것이 좋습니다.")
            elif rain_pop >= 70 and rain_pop < 90: output2 = output2.replace("@@날씨@@","\n강수확률이 높으므로 야외활동보단 실내활동을 권장합니다.\n\n⭐웨디의 꿀팁⭐ 실내에서 영화보는 것은 어떠신가요?")
            elif rain_pop >= 90: output2 = output2.replace("@@날씨@@","\n강수확률이 높으므로 가급적 실내에 있는 것이 쾌적할 것 같습니다.\n\n⭐웨디의 꿀팁⭐ 습도가 너무 높다면 제습기나 에어컨을 트시는 것을 추천합니다.")

        if "@@세차@@" in output2:
            if rain_pop < 30: output2 = output2.replace("@@세차@@","\n강수확률이 낮습니다. 필요시 세차를 하셔도 될 것 같습니다.")
            elif rain_pop >= 30 and rain_pop < 50: output2 = output2.replace("@@세차@@","\n강수확률이 있습니다. 세차는 다음에 하시는 것을 추천드립니다.")
            elif rain_pop >= 50 and rain_pop < 70: output2 = output2.replace("@@세차@@","\n강수확률이 높은 편입니다. 세차장과 주차장이 실내로 연결되어있지 않는 한 다음에 해주세요.\n\n⭐웨디의 꿀팁⭐ 자동차 내부를 먼저 청소하는 것도 좋은 방법입니다.")
            elif rain_pop >= 70 and rain_pop < 90: output2 = output2.replace("@@세차@@","\n강수확률이 높습니다. 세차는 다음에 하시는 것을 추천드립니다.\n\n⭐웨디의 꿀팁⭐ 장마철에는 먼지가 쌓이는 것을 방지하기 위해 덮개를 사용하는 것도 좋습니다.")
            elif rain_pop >= 90: output2 = output2.replace("@@세차@@","\n강수확률이 매우 높으므로 세차는 다른 날을 고려하셔야 합니다.\n\n⭐웨디의 꿀팁⭐ 가볍게 먼지를 턴 후 덮개를 사용하는 건 어떠실까요?")

        if "@@눅눅함@@" in output2:
            if temperature < 18:
                if humidity >= 75: output2 = output2.replace("@@눅눅함@@", "\n습도가 높아 눅눅함을 느낄 수 있습니다.\n\n⭐웨디의 꿀팁⭐ 눅눅함이 지속되는 장마철의 경우 방 안에 숯을 놓는 것도 좋습니다.")
                elif humidity >= 65: output2 = output2.replace("@@눅눅함@@", "\n적정습도 범주입니다.")
                elif humidity < 65: output2 = output2.replace("@@눅눅함@@", "\n습도가 낮아 건조함을 느낄 수 있습니다.\n\n⭐웨디의 꿀팁⭐ 주무실 때 젖은 수건을 옆에 두는 것을 추천합니다.")
            elif temperature <= 20:
                if humidity >= 65: output2 = output2.replace("@@눅눅함@@", "\n습도가 높아 눅눅함을 느낄 수 있습니다.\n\n⭐웨디의 꿀팁⭐ 곰팡이 예방을 위해 제습기나 에어컨을 트시는 것을 추천합니다.")
                elif humidity >= 55: output2 = output2.replace("@@눅눅함@@", "\n적정습도 범주입니다.")
                elif humidity < 55: output2 = output2.replace("@@눅눅함@@", "\n습도가 낮아 건조함을 느낄 수 있습니다.\n\n⭐웨디의 꿀팁⭐ 관엽 식물이 도움을 줄 수 있습니다.")
            elif temperature <= 23:
                if humidity >= 55: output2 = output2.replace("@@눅눅함@@", "\n습도가 높아 눅눅함을 느낄 수 있습니다.\n\n⭐웨디의 꿀팁⭐ 적절환 환기가 필요할 수 있습니다.")
                elif humidity >= 45: output2 = output2.replace("@@눅눅함@@", "\n적정습도 범주입니다.")
                elif humidity < 45: output2 = output2.replace("@@눅눅함@@", "\n습도가 낮아 건조함을 느낄 수 있습니다.\n\n⭐웨디의 꿀팁⭐ 가습기를 트는 것은 어떨까요?")
            elif temperature > 23:
                if humidity >= 45: output2 = output2.replace("@@눅눅함@@", "\n습도가 높아 눅눅함을 느낄 수 있습니다.\n\n⭐웨디의 꿀팁⭐ 환기를 하는 것을 추천드립니다.")
                elif humidity >= 35: output2 = output2.replace("@@눅눅함@@", "\n적정습도 범주입니다.")
                elif humidity < 35: output2 = output2.replace("@@눅눅함@@", "\n습도가 낮아 건조함을 느낄 수 있습니다.\n\n⭐웨디의 꿀팁⭐ 밤까지 건조하다면 물 한 컵을 옆에 두고 주무시는 것도 좋습니다.")

        if "@@건조함@@" in output2:
            if temperature < 18:
                if humidity >= 75: output2 = output2.replace("@@건조함@@", "\n습도가 높아 눅눅함을 느낄 수 있습니다.\n\n⭐웨디의 꿀팁⭐ 눅눅함이 지속되는 장마철의 경우 방 안에 숯을 놓는 것도 좋습니다.")
                elif humidity >= 65: output2 = output2.replace("@@건조함@@", "\n적정습도 범주입니다.")
                elif humidity < 65: output2 = output2.replace("@@건조함@@", "\n습도가 낮아 건조함을 느낄 수 있습니다.\n\n⭐웨디의 꿀팁⭐ 주무실 때 젖은 수건을 옆에 두는 것을 추천합니다.")
            elif temperature <= 20:
                if humidity >= 65: output2 = output2.replace("@@건조함@@", "\n습도가 높아 눅눅함을 느낄 수 있습니다.\n\n⭐웨디의 꿀팁⭐ 곰팡이 예방을 위해 제습기나 에어컨을 트시는 것을 추천합니다.")
                elif humidity >= 55: output2 = output2.replace("@@건조함@@", "\n적정습도 범주입니다.")
                elif humidity < 55: output2 = output2.replace("@@건조함@@", "\n습도가 낮아 건조함을 느낄 수 있습니다.\n\n⭐웨디의 꿀팁⭐ 관엽 식물이 도움을 줄 수 있습니다.")
            elif temperature <= 23:
                if humidity >= 55: output2 = output2.replace("@@건조함@@", "\n습도가 높아 눅눅함을 느낄 수 있습니다.\n\n⭐웨디의 꿀팁⭐ 적절환 환기가 필요할 수 있습니다.")
                elif humidity >= 45: output2 = output2.replace("@@건조함@@", "\n적정습도 범주입니다.")
                elif humidity < 45: output2 = output2.replace("@@건조함@@", "\n습도가 낮아 건조함을 느낄 수 있습니다.\n\n⭐웨디의 꿀팁⭐ 가습기를 트는 것은 어떨까요?")
            elif temperature > 23:
                if humidity >= 45: output2 = output2.replace("@@건조함@@", "\n습도가 높아 눅눅함을 느낄 수 있습니다.\n\n⭐웨디의 꿀팁⭐ 환기를 하는 것을 추천드립니다.")
                elif humidity >= 35: output2 = output2.replace("@@건조함@@", "\n적정습도 범주입니다.")
                elif humidity < 35: output2 = output2.replace("@@건조함@@", "\n습도가 낮아 건조함을 느낄 수 있습니다.\n\n⭐웨디의 꿀팁⭐ 밤까지 건조하다면 물 한 컵을 옆에 두고 주무시는 것도 좋습니다.")

        if "@@공기@@" in output2:
            if temperature < 18:
                if humidity >= 75: output2 = output2.replace("@@공기@@", "\n습도가 높아 눅눅함을 느낄 수 있습니다.\n\n⭐웨디의 꿀팁⭐ 눅눅함이 지속되는 장마철의 경우 방 안에 숯을 놓는 것도 좋습니다.")
                elif humidity >= 65: output2 = output2.replace("@@공기@@", "\n적정습도 범주입니다.")
                elif humidity < 65: output2 = output2.replace("@@공기@@", "\n습도가 낮아 건조함을 느낄 수 있습니다.\n\n⭐웨디의 꿀팁⭐ 주무실 때 젖은 수건을 옆에 두는 것을 추천합니다.")
            elif temperature <= 20:
                if humidity >= 65: output2 = output2.replace("@@공기@@", "\n습도가 높아 눅눅함을 느낄 수 있습니다.\n\n⭐웨디의 꿀팁⭐ 곰팡이 예방을 위해 제습기나 에어컨을 트시는 것을 추천합니다.")
                elif humidity >= 55: output2 = output2.replace("@@공기@@", "\n적정습도 범주입니다.")
                elif humidity < 55: output2 = output2.replace("@@공기@@", "\n습도가 낮아 건조함을 느낄 수 있습니다.\n\n⭐웨디의 꿀팁⭐ 관엽 식물이 도움을 줄 수 있습니다.")
            elif temperature <= 23:
                if humidity >= 55: output2 = output2.replace("@@공기@@", "\n습도가 높아 눅눅함을 느낄 수 있습니다.\n\n⭐웨디의 꿀팁⭐ 적절환 환기가 필요할 수 있습니다.")
                elif humidity >= 45: output2 = output2.replace("@@공기@@", "\n적정습도 범주입니다.")
                elif humidity < 45: output2 = output2.replace("@@공기@@", "\n습도가 낮아 건조함을 느낄 수 있습니다.\n\n⭐웨디의 꿀팁⭐ 가습기를 트는 것은 어떨까요?")
            elif temperature > 23:
                if humidity >= 45: output2 = output2.replace("@@공기@@", "\n습도가 높아 눅눅함을 느낄 수 있습니다.\n\n⭐웨디의 꿀팁⭐ 환기를 하는 것을 추천드립니다.")
                elif humidity >= 35: output2 = output2.replace("@@공기@@", "\n적정습도 범주입니다.")
                elif humidity < 35: output2 = output2.replace("@@공기@@", "\n습도가 낮아 건조함을 느낄 수 있습니다.\n\n⭐웨디의 꿀팁⭐ 밤까지 건조하다면 물 한 컵을 옆에 두고 주무시는 것도 좋습니다.")

        if "@@가습기@@" in output2:
            if humidity < 40: output2 = output2.replace("@@가습기@@", "\n건조합니다. 가습기를 트는 것을 권해드립니다.\n\n⭐웨디의 꿀팁⭐ 가습기 필터는 주기적으로 가는 것이 좋습니다.")
            elif humidity >= 40 and humidity <= 60: output2 = output2.replace("@@가습기@2", "\n실내 적정 습도인 40-60% 사이 입니다.")
            elif humidity > 60: output2 = output2.replace("@@가습기@@", "\n건조하지 않습니다. 가습기는 틀지 않으셔도 됩니다.")

        if "@@제습기@@" in output2:
            if humidity < 40: output2 = output2.replace("@@제습기@@", "\n습하지 않습니다. 제습기는 틀지 않으셔도 됩니다.")
            elif humidity >= 40 and humidity <= 60: output2 = output2.replace("@@제습기@@", "\n실내 적정 습도인 40-60% 사이 입니다.")
            elif humidity > 60: output2 = output2.replace("@@제습기@@", "\n실내 적정습도를 넘어섰습니다. 제습기를 트는 것을 권해드립니다.")

        if "@@곰팡이@@" in output2:
            if humidity > 60: output2 = output2.replace("@@곰팡이@@", "\n실내 적정습도를 넘어섰습니다. 상태가 유지된다면 곰팡이가 필 수 있으므로 제습기를 사용해주세요.\n\n⭐웨디의 꿀팁⭐ 제습기가 없으시다면 숯을 이용하는 것도 방법입니다.")
            elif humidity >= 40: output2 = output2.replace("@@곰팡이@@", "\n현재 실내 정적 습도인 40-60% 사이이나, 여름철에는 곰팡이에 유의해주세요.\n\n⭐웨디의 꿀팁⭐ 주변 환경에 따라 습하거나 건조할 수도 있습니다.")
            elif humidity < 40: output2 = output2.replace("@@곰팡이@@", "\n곰팡이가 잘 생기지 않을 것으로 보이지만, 건조할 수 있습니다.\n\n⭐웨디의 꿀팁⭐ 식물을 좋아하신다면 관엽식물을 키우시는 것도 방법입니다.")
        if "@@세탁기@@" in output2:
            if humidity < 40: output2 = output2.replace("@@세탁기@@", "\n습하지 않으므로 세탁을 하셔도 됩니다.")
            elif humidity >= 40 and humidity <= 60: output2 = output2.replace("@@세탁기@@", "\n실내 적정 습도인 40-60% 사이 입니다. 세탁을 하셔도 됩니다.")
            elif humidity > 60: output2 = output2.replace("@@세탁기@@", "\n실내 적정습도를 넘어섰습니다. 세탁을 하신다면 제습기나 에어컨으로 습도를 조절해주세요.")
        if "@@습도빨래@@" in output2:
            if humidity > 60:output2 = output2.replace("@@습도빨래@@", "\n실내 적정습도를 넘어섰습니다. 빨래를 하신다면 제습기나 에어컨으로 습도를 조절해주세요.")
            if 40<= humidity <=60:output2 = output2.replace("@@습도빨래@@","\n실내 적정 습도인 40-60% 사이 입니다. 빨래를 하셔도 됩니다.")
            if humidity <40: output2 = output2.replace("@@습도빨래@@", "\n습하지 않으므로 빨래를 하셔도 됩니다.")
        if "@@바람@@" in output2:
            if wind < 4: output2 = output2.replace("@@바람@@", "\n바람이 불지 않거나 잎사귀가 흔들릴 정도의 약한 바람이 불 수 있습니다.")
            elif wind >= 4 and wind < 7: output2 = output2.replace("@@바람@@", "\n체감상으로 시원할 정도의 바람이 붑니다.")
            elif wind >= 7 and wind < 9: output2 = output2.replace("@@바람@@", "\n사람의 따라 추위를 느낄 정도의 바람입니다.")
            elif wind >= 9 and wind < 14: output2 = output2.replace("@@바람@@", "\n나무 전체가 흔들리며 급격히 체온이 떨어질 수 있습니다.")
            elif wind >= 14: output2 = output2.replace("@@바람@@", "\n강풍주의보가 발령될 수 있으니 주의가 필요합니다.")
            elif wind >= 21: output2 = output2.replace("@@바람@@", "\n강풍경보가 발령될 수 있으니 물건 등의 주의가 필요합니다.")
        if "@@강풍@@" in output2:
            if wind < 9: output2 = output2.replace("@@강풍@@", "\n강풍으로 인한 피해는 걱정하지 않으셔도 됩니다.")
            elif wind >= 9 and wind < 14: output2 = output2.replace("@@강풍@@", "\n나무 전체가 흔들리며 급격히 체온이 떨어질 수 있습니다.")
            elif wind >= 14: output2 = output2.replace("@@강풍@@", "\n강풍주의보가 발령되니 주의가 필요합니다.")
            elif wind >= 21: output2 = output2.replace("@@강풍@@", "\n강풍경보가 발령되니 물건 등의 주의가 필요합니다.")

        if "@@바람막이@@" in output2:
            if wind >=10: output2 = output2.replace("@@바람막이@@", "\n바람이 많이 불어 체온이 떨어질 수 있으니 바람막이를 챙기세요.")
            else: output2 = output2.replace("@@바람막이@@", "\n바람이 많이 불지 않겠으나 노약자와 어린이는 바람막이가 필요할 수 있습니다.")

        if "@@파도@@" in output2:
            if wind <= 10: output2 = output2.replace("@@파도@@", "\n파도가 잔잔한 편으로 예상됩니다.")
            elif 10 < wind <= 14: output2 = output2.replace("@@파도@@", "\n흰파도가 생기며 파도가 높아지기 시작합니다.")
            elif 14 < wind <= 17: output2 = output2.replace("@@파도@@", "\n파장이 길어지고 마루의 끝이 거꾸로 된 파도가 생깁니다.\n\n⭐웨디의 꿀팁⭐ 해안가라면 보행이 힘드실 수 있습니다.")
            elif 18 < wind <= 21: output2 = output2.replace("@@파도@@", "\n물거품이 강풍에 날리기 시작합니다.")
            elif wind > 21: output2 = output2.replace("@@파도@@", "\n파도가 커지며 물보라 때문에 시정이 나빠집니다.\n\n⭐웨디의 꿀팁⭐ 바닷가에서 벗어나는 게 안전합니다.")
        if "@@눈예보@@" in output2:
            if snow == 0: output2 = output2.replace("@@눈예보@@", "\n눈이 오지 않습니다.")
            elif snow < 0.1: output2 = output2.replace("@@눈예보@@","\n육안으로는 볼 수 있으나 적설량을 젤 수 없는 눈이 날립니다.")
            elif snow < 0.2: output2 = output2.replace("@@눈예보@@","\n도로와 일상 생활에 영향을 주지 않습니다.")
            elif snow < 1: output2 = output2.replace("@@눈예보@@","\n길에 얇은 눈의 층이 형성될 수 있습니다.")
            elif snow < 5: output2 = output2.replace("@@눈예보@@","\n가볍게 쌓인 눈을 볼 수 있으며 이동시 약간의 주의가 필요합니다.")
            elif snow < 10: output2 = output2.replace("@@눈예보@@","\n주의보가 발령됩니다. 일상생활에 영향을 줄 수 있으며 제설 작업이 필요합니다.")
            elif snow < 20: output2 = output2.replace("@@눈예보@@","\n일반지역까지 경가 발령됩니다. 가급적 실내에 머무는 것을 권장합니다.")
            elif snow >= 20: output2 = output2.replace("@@눈예보@@","\n눈이 오지 않습니다.")
        if "@@온도@@" in output2:
            if temperature > 30: output2 = output2.replace("@@온도@@","\n무더위입니다. 열사병에 주의하시고, 실내에서 활동하세요.\n\n⭐웨디의 꿀팁⭐ 선크림을 발라 자외선 노출을 막아주세요!")
            elif temperature > 20: output2 = output2.replace("@@온도@@","\n더운 날씨 입니다. 일교차가 심할 수 있습니다.\n\n⭐웨디의 꿀팁⭐ 땀이 많이 났다면 수분을 충분히 섭취해야 해요.")
            elif temperature > 10: output2 = output2.replace("@@온도@@","\n일교차가 심할 수 있습니다. 쌀쌀한 날씨입니다.")
            elif temperature > 0: output2 = output2.replace("@@온도@@","\n조금 추운 날씨 입니다. 외투를 신경쓰는 것이 좋습니다.")
            elif temperature <= 0: output2 = output2.replace("@@온도@@","\n추운 날씨 입니다. 감기 조심하세요.")
        if "@@난방@@" in output2:
            if temperature < 10: output2 = output2.replace("@@난방@@", "\n추위가 느껴진다면 난방을 유지해주세요.")
            elif temperature < 20: output2 = output2.replace("@@난방@@", "\n춥다고 늦겨지거나 온도가 낮을 경우 작게 난방을 트는 것도 괜찮습니다.")
            elif temperature > 20: output2 = output2.replace("@@난방@@", "\n난방을 키기엔 기온이 높습니다.")

        if "@@냉방@@" in output2:
            if temperature > 30: output2 = output2.replace("@@냉방@@", "\n열사병의 위험이 있으니 적절히 냉방을 해주세요.\n\n⭐웨디의 꿀팁⭐ 가급적 실내에 머물러주세요.")
            elif temperature > 20: output2 = output2.replace("@@냉방@@", "\n온도가 높을 경우 작게 냉방을 트는 것도 괜찮습니다.")
            elif temperature > 10: output2 = output2.replace("@@냉방@@", "\n냉방을 켜기엔 기온이 낮습니다.")

        if "@@에어컨@@" in output2:
            if temperature > 30: output2 = output2.replace("@@에어컨@@", "\n열사병의 위험이 있으니 적절히 에어컨을 켜주세요.\n\n⭐웨디의 꿀팁⭐ 에너지 절약모드를 사용하시면 전기세 걱정을 덜 수 있습니다.")
            elif temperature > 20: output2 = output2.replace("@@에어컨@@", "\n온도가 높을 경우 약하게 에어컨을 트는 것도 괜찮습니다.\n\n⭐웨디의 꿀팁⭐ 얇은 옷으로 갈아입으시는 것도 좋습니다.")
            elif temperature > 10: output2 = output2.replace("@@에어컨@@", "\n에어컨을 켜기엔 기온이 낮습니다.")
        if "@@선풍기@@" in output2:
            if temperature > 30:output2 = output2.replace("@@선풍기@@", "\n열사병의 위험이 있으니 선풍기를 켜주세요.\n\n⭐웨디의 꿀팁⭐ 얇은 옷으로 갈아입으시는 것도 좋습니다.")
            elif temperature > 20: output2 = output2.replace("@@선풍기@@", "\n온도가 높을 경우 선풍기를 트는 것도 괜찮습니다.\n\n⭐웨디의 꿀팁⭐ 얇은 옷으로 갈아입으시는 것도 좋습니다.")
            elif temperature > 10: output2 = output2.replace("@@선풍기@@", "\n선풍기를 켜기엔 기온이 낮습니다.")

        ####################################

        # 3차 음식 템플릿
        if "@@시의성좋은음식@@" in output2:
            # 랜덤 키/밸류 쌍 추출
            random_key, random_value = random.choice(list(good_food.items()))
            # 문장 생성
            sentence = f"\n{random_key}은(는) {random_value} ╰(*°▽°*)╯"
            output2 = output2.replace(" 좋은음식", " " + random_key)
            output2 = output2.replace("@@시의성좋은음식@@", sentence)

        if "@@시의성나쁜음식@@" in output2:
            # 랜덤 키/밸류 쌍 추출
            random_key, random_value = random.choice(list(bad_food.items()))
            # 문장 생성
            sentence = f"\n{random_key}은(는) {random_value} `(*>﹏<*)′"
            output2 = output2.replace(" 나쁜음식", " " +random_key)
            output2 = output2.replace("@@시의성나쁜음식@@", sentence)
        if "@@일반성좋은음식@@" in output2:
            sentence = ""
            selected_items = random.sample(list(good_food.items()), 3)
            for food, description in selected_items:
                sentence += f"- {food}: {description}\n"
            output2 = output2.replace("@@일반성좋은음식@@", "\n\n" + sentence + "╰(*°▽°*)╯")
        if "@@일반성나쁜음식@@" in output2:
            sentence = ""
            selected_items = random.sample(list(bad_food.items()), 3)
            for food, description in selected_items:
                sentence += f"- {food}: {description}\n"
            output2 = output2.replace("@일반성나쁜음식@@", "\n\n" +sentence + "`(*>﹏<*)′")
        ###################################
        # 3차 옷 템플릿
        if "@@온도별옷@@" in output2:
            if temperature <= 15: output2 = output2.replace("@@온도별옷@@","\n해당 기온에서의 추천 옷차림은 얇은 긴팔 티셔츠나, 가벼운 가디건이나 니트를 추천합니다. 때에 따라서 선선함을 느낄 수 있는 날씨입니다.")
            elif temperature <= 25: output2 = output2.replace("@@온도별옷@@","\n해당 기온에서의 추천 옷차림은 얇은 긴팔 셔츠, 면바지, 가벼운 재킷과 같이\n상대적으로 선선한 날씨에 대비해 약간의 보온 효과를 주면서도 통기성이 좋은 소재로 만든 옷을 입는 것이 좋습니다.")
            else:output2 = output2.replace("@@온도별옷@@","\n해당 기온에서의 추천 옷차림은 반팔 셔츠, 반바지, 면이나 리넨 소재의 옷과 같이\n상대적으로 가볍고 통기성이 좋으며 땀을 흡수하고 빨리 마르는 소재의 옷이 좋습니다.")


        if "좋고습니다." in output2:
            output2  = output2.replace("좋고습니다.","좋습니다.")
        ###################################
        print("정보 기준 날짜/시간:",timestamp)
        print("완성문장:",output2)





        '''
        if index == 1:

            #html 링크 출력
        '''
        print('======================')

    else:
        output1 = output1.replace("{", "").replace("}", "")
        if "좋고습니다." in output1:
            output1  = output1.replace("좋고습니다.","좋습니다.")
        print("완성문장:", output1)
        print('======================')
# Out:
# <현재 시각: 2024-06-14 12:57:41>
# ======================
# 사용질문: 더운데?
# 정보 기준 날짜/시간: 2024-06-14
# 완성문장: 여름철 먹기 좋은 음식을 몇 가지 추천해 드리겠습니다!
#
# - 추어탕: 여름철 보양식입니다. 지역마다 특징이 다르다고 합니다.
# - 갈치조림: 제철 요리입니다. 제주도에서 갈치가 유명합니다.
# - 비빔국수: 시원하고 매운 양념이 입맛을 돋움니다.
# ╰(*°▽°*)╯
# ======================
# 사용질문: 더운데
# 정보 기준 날짜/시간: 2024-06-14
# 완성문장: 여름철 먹기 좋은 음식을 몇 가지 추천해 드리겠습니다!
#
# - 아이스크림: 열감해소와 당분보풍에 뛰어난 간식입니다.
# - 막국수: 물막국수, 비빔막국수 등 다양하며 일부 지역마다 먹는 방법이 재미있는 여름 요리입니다.
# - 비빔냉면: 시원하고 매운 양념이 입맛을 돋움니다.
# ╰(*°▽°*)╯
# ======================
# 사용질문: 추운데
# 완성문장: 정말 추운 날이에요.
# ======================
# 사용질문: 종료

# %%
output2 = "여름철 먹기 좋은 음식을 몇 가지 추천해 드리겠습니다! @@일반성좋은음식@@"
print("@@일반성좋은음식@@ in output2:", "@@일반성좋은음식@@" in output2)

if "@@일반성좋은음식@@" in output2:
    print('@#@#@')
    sentence = ""
    selected_items = random.sample(list(good_food.items()), 3)
    for food, description in selected_items:
        sentence += f"- {food}: {description}\n"
    output2 = output2.replace("@@일반성좋은음식@@", sentence + "╰(*°▽°*)╯")

print("Modified output2:", output2)
# Out:
# @@일반성좋은음식@@ in output2: True
# @#@#@
# Modified output2: 여름철 먹기 좋은 음식을 몇 가지 추천해 드리겠습니다! - 팥빙수: 여름 대표 간식입니다. 다양한 빙수들이 있습니다.
# - 냉모밀: 차가운 음식으로 열감 해소에 도움이 됩니다.
# - 비빔냉면: 시원하고 매운 양념이 입맛을 돋움니다.
# ╰(*°▽°*)╯

# %% [markdown]
# ```
# - "날짜, 시간대, 시간"
# - "날짜, 시간대"
# - "날짜, 시간"
# - "날짜"
# - "시간대, 시간"
# - "시간대"
# - "시간"
# - "없음"
#
# ```

# %% [markdown]
# - 5/20 템플릿 테스트

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 5/17 파급효과 X 기본 질문 테스트

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 안녕하세요?
#
# 당신은 누구인가요?
#
# 현재 기온은 어떤가요?
#
# 내일 습도는 어떻게 되나요?
#
# 2일 뒤 강수확률이 어떤가요?
#
# 오늘 낮에 날씨는 어떨까요?
#
# 내일 저녁의 풍속은 몇인가요?
#
# 3일 뒤 오후에는 대기압이 얼마나 될까요?
